# %%
#!pip3 install pandas

# %%
import pandas as pd
import numpy as np

# %%
file1 = pd.read_csv('file1.csv')
display(file1.head(50))
display(file1.tail())
file1.shape
# Out:
#    Customer          ST GENDER             Education Customer Lifetime Value  \
# 0   RB50392  Washington    NaN                Master                     NaN
# 1   QZ44356     Arizona      F              Bachelor              697953.59%
# 2   AI49188      Nevada      F              Bachelor             1288743.17%
# 3   WW63253  California      M              Bachelor              764586.18%
# 4   GA49547  Washington      M  High School or Below              536307.65%
# 5   OC83172      Oregon      F              Bachelor              825629.78%
# 6   XZ87318      Oregon      F               College              538089.86%
# 7   CF85061     Arizona      M                Master              721610.03%
# 8   DY87989      Oregon      M              Bachelor             2412750.40%
# 9   BQ94931      Oregon      F               College              738817.81%
# 10  SX51350  California      M               College              473899.20%
# ...

# %%
file2 = pd.read_csv('file2.csv')
display(file2.head(50))
display(file2.tail())
file2.shape
# Out:
#    Customer          ST GENDER             Education Customer Lifetime Value  \
# 0   GS98873     Arizona      F              Bachelor              323912.47%
# 1   CW49887  California      F                Master              462680.11%
# 2   MY31220  California      F               College              899704.02%
# 3   UH35128      Oregon      F               College             2580706.30%
# 4   WH52799     Arizona      F               College              380812.21%
# 5   WL99637     Arizona      M              Bachelor              761413.80%
# 6   UC84059  California      F                Master              689845.53%
# 7   HW62747      Oregon      M               College              229837.92%
# 8   BH11344      Oregon      F                Doctor              280669.61%
# 9   TX28465      Nevada      M               College              520611.82%
# 10  OK56965  California      F              Bachelor             4570865.34%
# ...

# %%
file3 = pd.read_csv('file3.csv')
display(file3.head(50))
display(file3.tail())
file3.shape
# Out:
#    Customer       State  Customer Lifetime Value             Education Gender  \
# 0   SA25987  Washington              3479.137523  High School or Below      M
# 1   TB86706     Arizona              2502.637401                Master      M
# 2   ZL73902      Nevada              3265.156348              Bachelor      F
# 3   KX23516  California              4455.843406  High School or Below      F
# 4   FN77294  California              7704.958480  High School or Below      M
# 5   VI78454     Arizona              2750.705045               College      M
# 6   FP59138      Oregon             13024.130120                Master      M
# 7   XN62489      Oregon              2538.626320              Bachelor      M
# 8   GP66031  California              2585.955652               College      F
# 9   IX68587      Nevada              5096.673223                Master      F
# 10  HX17929  California             10083.486880  High School or Below      F
# ...

# %%
#standardize header names
file1.columns=[e.lower().replace(' ', '_') for e in file1.columns] 
file1.columns
# Out:
# Index(['customer', 'st', 'gender', 'education', 'customer_lifetime_value',
#        'income', 'monthly_premium_auto', 'number_of_open_complaints',
#        'policy_type', 'vehicle_class', 'total_claim_amount'],
#       dtype='object')

# %%
file2.columns=[e.lower().replace(' ', '_') for e in file2.columns] 
file2.columns
# Out:
# Index(['customer', 'st', 'gender', 'education', 'customer_lifetime_value',
#        'income', 'monthly_premium_auto', 'number_of_open_complaints',
#        'total_claim_amount', 'policy_type', 'vehicle_class'],
#       dtype='object')

# %%
file3.columns=[e.lower().replace(' ', '_') for e in file3.columns] 
file3.columns
# Out:
# Index(['customer', 'state', 'customer_lifetime_value', 'education', 'gender',
#        'income', 'monthly_premium_auto', 'number_of_open_complaints',
#        'policy_type', 'total_claim_amount', 'vehicle_class'],
#       dtype='object')

# %%
# renaming columns
file1 = file1.rename(columns={'st':'state'})
file1.head()
#file1.shape
# Out:
#   customer       state gender             education customer_lifetime_value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#     income  monthly_premium_auto number_of_open_complaints     policy_type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
#    vehicle_class  total_claim_amount
# ...

# %%
# renaming columns
file2 = file2.rename(columns={'st':'state'})
file2.head()
#file2.shape
# Out:
#   customer       state gender education customer_lifetime_value  income  \
# 0  GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1  CW49887  California      F    Master              462680.11%   79487
# 2  MY31220  California      F   College              899704.02%   54230
# 3  UH35128      Oregon      F   College             2580706.30%   71210
# 4  WH52799     Arizona      F   College              380812.21%   94903
#
#    monthly_premium_auto number_of_open_complaints  total_claim_amount  \
# 0                    88                    1/0/00               633.6
# 1                   114                    1/0/00               547.2
# 2                   112                    1/0/00               537.6
# 3                   214                    1/1/00              1027.2
# 4                    94                    1/0/00               451.2
#
#       policy_type  vehicle_class
# 0   Personal Auto  Four-Door Car
# 1    Special Auto            SUV
# ...

# %%
file1 = file1[['customer', 'state', 'gender','education','customer_lifetime_value','income','monthly_premium_auto','number_of_open_complaints', 'policy_type', 'vehicle_class', 'total_claim_amount']]
file1.head()
# Out:
#   customer       state gender             education customer_lifetime_value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#     income  monthly_premium_auto number_of_open_complaints     policy_type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
#    vehicle_class  total_claim_amount
# ...

# %%
file2 = file2[['customer', 'state', 'gender','education','customer_lifetime_value','income','monthly_premium_auto','number_of_open_complaints', 'policy_type', 'vehicle_class', 'total_claim_amount']]
file2.head()
# Out:
#   customer       state gender education customer_lifetime_value  income  \
# 0  GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1  CW49887  California      F    Master              462680.11%   79487
# 2  MY31220  California      F   College              899704.02%   54230
# 3  UH35128      Oregon      F   College             2580706.30%   71210
# 4  WH52799     Arizona      F   College              380812.21%   94903
#
#    monthly_premium_auto number_of_open_complaints     policy_type  \
# 0                    88                    1/0/00   Personal Auto
# 1                   114                    1/0/00    Special Auto
# 2                   112                    1/0/00   Personal Auto
# 3                   214                    1/1/00   Personal Auto
# 4                    94                    1/0/00  Corporate Auto
#
#    vehicle_class  total_claim_amount
# 0  Four-Door Car               633.6
# 1            SUV               547.2
# ...

# %%
file3 = file3[['customer', 'state', 'gender','education','customer_lifetime_value','income','monthly_premium_auto','number_of_open_complaints', 'policy_type', 'vehicle_class', 'total_claim_amount']]
file3.head()
# Out:
#   customer       state gender             education  customer_lifetime_value  \
# 0  SA25987  Washington      M  High School or Below              3479.137523
# 1  TB86706     Arizona      M                Master              2502.637401
# 2  ZL73902      Nevada      F              Bachelor              3265.156348
# 3  KX23516  California      F  High School or Below              4455.843406
# 4  FN77294  California      M  High School or Below              7704.958480
#
#    income  monthly_premium_auto  number_of_open_complaints    policy_type  \
# 0       0                   104                          0  Personal Auto
# 1       0                    66                          0  Personal Auto
# 2   25820                    82                          0  Personal Auto
# 3       0                   121                          0  Personal Auto
# 4   30366                   101                          2  Personal Auto
#
#    vehicle_class  total_claim_amount
# ...

# %%
file_new = pd.concat([file1,file2,file3], axis=0)
file_new.shape
# Out:
# (12074, 11)

# %%
file_new.head()
# Out:
#   customer       state gender             education customer_lifetime_value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#     income  monthly_premium_auto number_of_open_complaints     policy_type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
#    vehicle_class  total_claim_amount
# ...

# %%
# # Rearranging columns: 
file_new = file_new[['customer','gender', 'education'  ,'state','income','customer_lifetime_value','vehicle_class','monthly_premium_auto','policy_type', 'number_of_open_complaints' ,'total_claim_amount']]
file_new.head()
# Out:
#   customer gender             education       state   income  \
# 0  RB50392    NaN                Master  Washington      0.0
# 1  QZ44356      F              Bachelor     Arizona      0.0
# 2  AI49188      F              Bachelor      Nevada  48767.0
# 3  WW63253      M              Bachelor  California      0.0
# 4  GA49547      M  High School or Below  Washington  36357.0
#
#   customer_lifetime_value  vehicle_class  monthly_premium_auto  \
# 0                     NaN  Four-Door Car                1000.0
# 1              697953.59%  Four-Door Car                  94.0
# 2             1288743.17%   Two-Door Car                 108.0
# 3              764586.18%            SUV                 106.0
# 4              536307.65%  Four-Door Car                  68.0
#
#       policy_type number_of_open_complaints  total_claim_amount
# 0   Personal Auto                    1/0/00            2.704934
# 1   Personal Auto                    1/0/00         1131.464935
# ...

# %%
# Which columns are numerical
file_num=file_new._get_numeric_data()
file_num.head()
# Out:
#     income  monthly_premium_auto  total_claim_amount
# 0      0.0                1000.0            2.704934
# 1      0.0                  94.0         1131.464935
# 2  48767.0                 108.0          566.472247
# 3      0.0                 106.0          529.881344
# 4  36357.0                  68.0           17.269323

# %%
#Which columns are categorical
file_cat=file_new.select_dtypes('object')
file_cat.head()
# Out:
#   customer gender             education       state customer_lifetime_value  \
# 0  RB50392    NaN                Master  Washington                     NaN
# 1  QZ44356      F              Bachelor     Arizona              697953.59%
# 2  AI49188      F              Bachelor      Nevada             1288743.17%
# 3  WW63253      M              Bachelor  California              764586.18%
# 4  GA49547      M  High School or Below  Washington              536307.65%
#
#    vehicle_class     policy_type number_of_open_complaints
# 0  Four-Door Car   Personal Auto                    1/0/00
# 1  Four-Door Car   Personal Auto                    1/0/00
# 2   Two-Door Car   Personal Auto                    1/0/00
# 3            SUV  Corporate Auto                    1/0/00
# 4  Four-Door Car   Personal Auto                    1/0/00

# %%
print(file_new.columns.tolist())
# Out:
# ['customer', 'gender', 'education', 'state', 'income', 'customer_lifetime_value', 'vehicle_class', 'monthly_premium_auto', 'policy_type', 'number_of_open_complaints', 'total_claim_amount']

# %%
#Delete the column education and the number of open complaints
file_new1 = file_new.drop(['education','number_of_open_complaints'], axis =1)
display(file_new.tail())
# Out:
#      customer gender education       state   income customer_lifetime_value  \
# 7065  LA72316      M  Bachelor  California  71941.0             23405.98798
# 7066  PK87824      F   College  California  21604.0             3096.511217
# 7067  TD14365      M  Bachelor  California      0.0             8163.890428
# 7068  UP19263      M   College  California  21941.0             7524.442436
# 7069  Y167826      M   College  California      0.0             2611.836866
#
#       vehicle_class  monthly_premium_auto     policy_type  \
# 7065  Four-Door Car                  73.0   Personal Auto
# 7066  Four-Door Car                  79.0  Corporate Auto
# 7067  Four-Door Car                  85.0  Corporate Auto
# 7068  Four-Door Car                  96.0   Personal Auto
# 7069   Two-Door Car                  77.0  Corporate Auto
#
#      number_of_open_complaints  total_claim_amount
# 7065                         0          198.234764
# 7066                         0          379.200000
# ...

# %%
#Correct the values in the column customer lifetime value.They are given as a percent ,
#so multiply them by 100 and change dtype to numerical type.
file_new1['customer_lifetime_value'] = file_new['customer_lifetime_value']*100
display(file_new)
# Out:
#      customer gender             education       state   income  \
# 0     RB50392    NaN                Master  Washington      0.0
# 1     QZ44356      F              Bachelor     Arizona      0.0
# 2     AI49188      F              Bachelor      Nevada  48767.0
# 3     WW63253      M              Bachelor  California      0.0
# 4     GA49547      M  High School or Below  Washington  36357.0
# ...       ...    ...                   ...         ...      ...
# 7065  LA72316      M              Bachelor  California  71941.0
# 7066  PK87824      F               College  California  21604.0
# 7067  TD14365      M              Bachelor  California      0.0
# 7068  UP19263      M               College  California  21941.0
# 7069  Y167826      M               College  California      0.0
#
#      customer_lifetime_value  vehicle_class  monthly_premium_auto  \
# 0                        NaN  Four-Door Car                1000.0
# ...

# %%
file_new1['customer_lifetime_value'] =  pd.to_numeric(file_new1['customer_lifetime_value'], errors='coerce')
file_new1.head(20)
# Out:
#    customer gender       state   income  customer_lifetime_value  \
# 0   RB50392    NaN  Washington      0.0                      NaN
# 1   QZ44356      F     Arizona      0.0                      NaN
# 2   AI49188      F      Nevada  48767.0                      NaN
# 3   WW63253      M  California      0.0                      NaN
# 4   GA49547      M  Washington  36357.0                      NaN
# 5   OC83172      F      Oregon  62902.0                      NaN
# 6   XZ87318      F      Oregon  55350.0                      NaN
# 7   CF85061      M     Arizona      0.0                      NaN
# 8   DY87989      M      Oregon  14072.0                      NaN
# 9   BQ94931      F      Oregon  28812.0                      NaN
# 10  SX51350      M  California      0.0                      NaN
# 11  VQ65197    NaN  California      0.0                      NaN
# 12  DP39365    NaN  California  77026.0                      NaN
# ...

# %%
#Check for duplicates and remove them
file_new1 = file_new1.drop_duplicates()
print(file_new1.shape)
# Out:
# (9135, 9)

# %%
#Filter out customers  who have an income of 0 or less
file_new[(file_new['customer']) (file_new['income']<0)]
# & = AND, | = OR
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12440\497293395.py in <module>
#       1 #Filter out customers  who have an income of 0 or less
# ----> 2 file_new[(file_new['customer']) (file_new['income']<0)]
#       3 # & = AND, | = OR
#
# TypeError: 'Series' object is not callable
